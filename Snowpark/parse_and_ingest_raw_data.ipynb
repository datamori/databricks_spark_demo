# %%
from snowflake.snowpark import *
import snowflake.snowpark.functions as F

# %%
connection_parameters = {
    "account": "whpxseb-ke63785",
    "user": "<username>",
    "password": "<password>",
    "role": "ACCOUNTADMIN",
    "warehouse": "MYWH2",
    "database": "EV_POP_DATA2",
    "schema": "EV_POP_SCHEMA"}

db_table = 'RAW_DATA'

# %%
sf_session = Session.builder.configs(connection_parameters).create()

# %%
snow_df = sf_session.sql('SELECT JSON_SRC:meta as meta FROM RAW_DATA').dropna()
snow_df.show()
# Out:
# ------------------------------------------------------
# |"META"                                              |
# ------------------------------------------------------
# |{                                                   |
# |  "view": {                                         |
# |    "approvals": [                                  |
# |      {                                             |
# |        "reviewedAt": 1559931329,                   |
# |        "reviewedAutomatically": true,              |
# |        "state": "approved",                        |
# |        "submissionDetails": {                      |
# |          "permissionType": "READ"                  |
# |        },                                          |
# |        "submissionId": 4774840,                    |
# |        "submissionObject": "public_audience_re...  |
# |        "submissionOutcome": "change_audience",     |
# |        "submissionOutcomeApplication": {           |
# |          "failureCount": 0,                        |
# |          "status": "success"                       |
# |        },                                          |
# |        "submittedAt": 1559931329,                  |
# |        "submitter": {                              |
# |          "displayName": "Department of Licensi...  |
# |          "id": "eagg-6py7"                         |
# |        },                                          |
# |        "workflowId": 2106                          |
# |      }                                             |
# |    ],                                              |
# |    "assetType": "dataset",                         |
# |    "attribution": "Washington State Department...  |
# |    "averageRating": 0,                             |
# |    "category": "Transportation",                   |
# |    "clientContext": {                              |
# |      "clientContextVariables": [],                 |
# |      "inheritedVariables": {}                      |
# |    },                                              |
# |    "columns": [                                    |
# |      {                                             |
# |        "dataTypeName": "meta_data",                |
# |        "fieldName": ":sid",                        |
# |        "flags": [                                  |
# |          "hidden"                                  |
# |        ],                                          |
# |        "format": {},                               |
# |        "id": -1,                                   |
# |        "name": "sid",                              |
# |        "position": 0,                              |
# |        "renderTypeName": "meta_data"               |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "meta_data",                |
# |        "fieldName": ":id",                         |
# |        "flags": [                                  |
# |          "hidden"                                  |
# |        ],                                          |
# |        "format": {},                               |
# |        "id": -1,                                   |
# |        "name": "id",                               |
# |        "position": 0,                              |
# |        "renderTypeName": "meta_data"               |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "meta_data",                |
# |        "fieldName": ":position",                   |
# |        "flags": [                                  |
# |          "hidden"                                  |
# |        ],                                          |
# |        "format": {},                               |
# |        "id": -1,                                   |
# |        "name": "position",                         |
# |        "position": 0,                              |
# |        "renderTypeName": "meta_data"               |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "meta_data",                |
# |        "fieldName": ":created_at",                 |
# |        "flags": [                                  |
# |          "hidden"                                  |
# |        ],                                          |
# |        "format": {},                               |
# |        "id": -1,                                   |
# |        "name": "created_at",                       |
# |        "position": 0,                              |
# |        "renderTypeName": "meta_data"               |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "meta_data",                |
# |        "fieldName": ":created_meta",               |
# |        "flags": [                                  |
# |          "hidden"                                  |
# |        ],                                          |
# |        "format": {},                               |
# |        "id": -1,                                   |
# |        "name": "created_meta",                     |
# |        "position": 0,                              |
# |        "renderTypeName": "meta_data"               |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "meta_data",                |
# |        "fieldName": ":updated_at",                 |
# |        "flags": [                                  |
# |          "hidden"                                  |
# |        ],                                          |
# |        "format": {},                               |
# |        "id": -1,                                   |
# |        "name": "updated_at",                       |
# |        "position": 0,                              |
# |        "renderTypeName": "meta_data"               |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "meta_data",                |
# |        "fieldName": ":updated_meta",               |
# |        "flags": [                                  |
# |          "hidden"                                  |
# |        ],                                          |
# |        "format": {},                               |
# |        "id": -1,                                   |
# |        "name": "updated_meta",                     |
# |        "position": 0,                              |
# |        "renderTypeName": "meta_data"               |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "meta_data",                |
# |        "fieldName": ":meta",                       |
# |        "flags": [                                  |
# |          "hidden"                                  |
# |        ],                                          |
# |        "format": {},                               |
# |        "id": -1,                                   |
# |        "name": "meta",                             |
# |        "position": 0,                              |
# |        "renderTypeName": "meta_data"               |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "text",                     |
# |        "description": "The 1st 10 characters o...  |
# |        "fieldName": "vin_1_10",                    |
# |        "format": {},                               |
# |        "id": 561974342,                            |
# |        "name": "VIN (1-10)",                       |
# |        "position": 1,                              |
# |        "renderTypeName": "text",                   |
# |        "tableColumnId": 79309982                   |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "text",                     |
# |        "description": "The county in which the...  |
# |        "fieldName": "county",                      |
# |        "format": {},                               |
# |        "id": 561974343,                            |
# |        "name": "County",                           |
# |        "position": 2,                              |
# |        "renderTypeName": "text",                   |
# |        "tableColumnId": 79309981                   |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "text",                     |
# |        "description": "The city in which the r...  |
# |        "fieldName": "city",                        |
# |        "format": {},                               |
# |        "id": 561974344,                            |
# |        "name": "City",                             |
# |        "position": 3,                              |
# |        "renderTypeName": "text",                   |
# |        "tableColumnId": 79309980                   |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "text",                     |
# |        "description": "The state in which the ...  |
# |        "fieldName": "state",                       |
# |        "format": {},                               |
# |        "id": 561974345,                            |
# |        "name": "State",                            |
# |        "position": 4,                              |
# |        "renderTypeName": "text",                   |
# |        "tableColumnId": 80218820                   |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "text",                     |
# |        "description": "The 5 digit zip code in...  |
# |        "fieldName": "zip_code",                    |
# |        "format": {},                               |
# |        "id": 561974346,                            |
# |        "name": "Postal Code",                      |
# |        "position": 5,                              |
# |        "renderTypeName": "text",                   |
# |        "tableColumnId": 79309971                   |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "text",                     |
# |        "description": "The model year of the v...  |
# |        "fieldName": "model_year",                  |
# |        "format": {},                               |
# |        "id": 561974347,                            |
# |        "name": "Model Year",                       |
# |        "position": 6,                              |
# |        "renderTypeName": "text",                   |
# |        "tableColumnId": 79309970                   |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "text",                     |
# |        "description": "The manufacturer of the...  |
# |        "fieldName": "make",                        |
# |        "format": {},                               |
# |        "id": 561974348,                            |
# |        "name": "Make",                             |
# |        "position": 7,                              |
# |        "renderTypeName": "text",                   |
# |        "tableColumnId": 79309979                   |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "text",                     |
# |        "description": "The model of the vehicl...  |
# |        "fieldName": "model",                       |
# |        "format": {},                               |
# |        "id": 561974349,                            |
# |        "name": "Model",                            |
# |        "position": 8,                              |
# |        "renderTypeName": "text",                   |
# |        "tableColumnId": 79309978                   |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "text",                     |
# |        "description": "This distinguishes the ...  |
# |        "fieldName": "ev_type",                     |
# |        "format": {                                 |
# |          "align": "right"                          |
# |        },                                          |
# |        "id": 561974350,                            |
# |        "name": "Electric Vehicle Type",            |
# |        "position": 9,                              |
# |        "renderTypeName": "text",                   |
# |        "tableColumnId": 79309976                   |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "text",                     |
# |        "description": "This categorizes vehicl...  |
# |        "fieldName": "cafv_type",                   |
# |        "format": {                                 |
# |          "align": "right"                          |
# |        },                                          |
# |        "id": 561974351,                            |
# |        "name": "Clean Alternative Fuel Vehicle...  |
# |        "position": 10,                             |
# |        "renderTypeName": "text",                   |
# |        "tableColumnId": 79309975                   |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "number",                   |
# |        "description": "Describes how far a veh...  |
# |        "fieldName": "electric_range",              |
# |        "format": {                                 |
# |          "align": "right"                          |
# |        },                                          |
# |        "id": 561974352,                            |
# |        "name": "Electric Range",                   |
# |        "position": 11,                             |
# |        "renderTypeName": "number",                 |
# |        "tableColumnId": 79309974                   |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "number",                   |
# |        "description": "This is the lowest Manu...  |
# |        "fieldName": "base_msrp",                   |
# |        "format": {                                 |
# |          "align": "right"                          |
# |        },                                          |
# |        "id": 561974353,                            |
# |        "name": "Base MSRP",                        |
# |        "position": 12,                             |
# |        "renderTypeName": "number",                 |
# |        "tableColumnId": 79310342                   |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "number",                   |
# |        "description": "The specific section of...  |
# |        "fieldName": "legislative_district",        |
# |        "format": {                                 |
# |          "align": "center"                         |
# |        },                                          |
# |        "id": 561974354,                            |
# |        "name": "Legislative District",             |
# |        "position": 13,                             |
# |        "renderTypeName": "number",                 |
# |        "tableColumnId": 140620854                  |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "text",                     |
# |        "description": "Unique number assigned ...  |
# |        "fieldName": "dol_vehicle_id",              |
# |        "format": {},                               |
# |        "id": 561974355,                            |
# |        "name": "DOL Vehicle ID",                   |
# |        "position": 14,                             |
# |        "renderTypeName": "text",                   |
# |        "tableColumnId": 82051518                   |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "point",                    |
# |        "description": "The center of the ZIP C...  |
# |        "fieldName": "geocoded_column",             |
# |        "format": {},                               |
# |        "id": 561974356,                            |
# |        "name": "Vehicle Location",                 |
# |        "position": 15,                             |
# |        "renderTypeName": "point",                  |
# |        "tableColumnId": 87270515                   |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "text",                     |
# |        "description": "This is the electric po...  |
# |        "fieldName": "electric_utility",            |
# |        "format": {},                               |
# |        "id": 561974358,                            |
# |        "name": "Electric Utility",                 |
# |        "position": 17,                             |
# |        "renderTypeName": "text",                   |
# |        "tableColumnId": 141400529                  |
# |      },                                            |
# |      {                                             |
# |        "dataTypeName": "text",                     |
# |        "description": "The census tract identi...  |
# |        "fieldName": "_2020_census_tract",          |
# |        "format": {},                               |
# |        "id": 561974362,                            |
# |        "name": "2020 Census Tract",                |
# |        "position": 18,                             |
# |        "renderTypeName": "text",                   |
# |        "tableColumnId": 142655072                  |
# |      },                                            |
# |      {                                             |
# |        "computationStrategy": {                    |
# |          "parameters": {                           |
# |            "primary_key": "_feature_id",           |
# |            "region": "_x4ys-rtnd"                  |
# |          },                                        |
# |          "source_columns": [                       |
# |            "geocoded_column"                       |
# |          ],                                        |
# |          "type": "georegion_match_on_point"        |
# |        },                                          |
# |        "dataTypeName": "number",                   |
# |        "description": "",                          |
# |        "fieldName": ":@computed_region_x4ys_rt...  |
# |        "format": {},                               |
# |        "id": 561974360,                            |
# |        "name": "Counties",                         |
# |        "position": 19,                             |
# |        "renderTypeName": "number",                 |
# |        "tableColumnId": 87270516                   |
# |      },                                            |
# |      {                                             |
# |        "computationStrategy": {                    |
# |          "parameters": {                           |
# |            "primary_key": "_feature_id",           |
# |            "region": "_fny7-vc3j"                  |
# |          },                                        |
# |          "source_columns": [                       |
# |            "geocoded_column"                       |
# |          ],                                        |
# |          "type": "georegion_match_on_point"        |
# |        },                                          |
# |        "dataTypeName": "number",                   |
# |        "description": "",                          |
# |        "fieldName": ":@computed_region_fny7_vc...  |
# |        "format": {},                               |
# |        "id": 561974361,                            |
# |        "name": "Congressional Districts",          |
# |        "position": 20,                             |
# |        "renderTypeName": "number",                 |
# |        "tableColumnId": 87270517                   |
# |      },                                            |
# |      {                                             |
# |        "computationStrategy": {                    |
# |          "parameters": {                           |
# |            "primary_key": "_feature_id",           |
# |            "region": "_8ddd-yn5v"                  |
# |          },                                        |
# |          "source_columns": [                       |
# |            "geocoded_column"                       |
# |          ],                                        |
# |          "type": "georegion_match_on_point"        |
# |        },                                          |
# |        "dataTypeName": "number",                   |
# |        "description": "",                          |
# |        "fieldName": ":@computed_region_8ddd_yn...  |
# |        "format": {},                               |
# |        "id": 561974359,                            |
# |        "name": "WAOFM - GIS - Legislative Dist...  |
# |        "position": 21,                             |
# |        "renderTypeName": "number",                 |
# |        "tableColumnId": 87270518                   |
# |      }                                             |
# |    ],                                              |
# |    "createdAt": 1555435581,                        |
# |    "description": "This dataset shows the Batt...  |
# |    "displayType": "table",                         |
# |    "downloadCount": 52628,                         |
# |    "flags": [                                      |
# |      "default",                                    |
# |      "ownerMayBeContacted",                        |
# |      "restorable",                                 |
# |      "restorePossibleForType"                      |
# |    ],                                              |
# |    "grants": [                                     |
# |      {                                             |
# |        "flags": [                                  |
# |          "public"                                  |
# |        ],                                          |
# |        "inherited": false,                         |
# |        "type": "viewer"                            |
# |      }                                             |
# |    ],                                              |
# |    "hideFromCatalog": false,                       |
# |    "hideFromDataJson": false,                      |
# |    "id": "f6w7-q2d2",                              |
# |    "metadata": {                                   |
# |      "availableDisplayTypes": [                    |
# |        "table",                                    |
# |        "fatrow",                                   |
# |        "page"                                      |
# |      ],                                            |
# |      "custom_fields": {                            |
# |        "Identification": {                         |
# |          "Metadata Language": "English",           |
# |          "Originator": "Research and Analysis ...  |
# |        },                                          |
# |        "Notes": {                                  |
# |          "1. ": "A Battery Electric Vehicle (B...  |
# |          "2. ": "Clean Alternative Fuel Vehicl...  |
# |          "3. ": "Monthly count of vehicles for...  |
# |          "4. ": "Electric Range is no longer m...  |
# |          "5. ": "Field 'Electric Utility' was ...  |
# |          "6. ": "Field '2020 Census Tract' was...  |
# |        },                                          |
# |        "Temporal": {                               |
# |          "Period of Time": "Data includes Batt...  |
# |          "Posting Frequency": "Monthly"            |
# |        }                                           |
# |      },                                            |
# |      "rowLabel": "Vehicle"                         |
# |    },                                              |
# |    "name": "Electric Vehicle Population Data",     |
# |    "newBackend": true,                             |
# |    "numberOfComments": 0,                          |
# |    "oid": 38591322,                                |
# |    "owner": {                                      |
# |      "displayName": "Department of Licensing",     |
# |      "flags": [                                    |
# |        "acceptedEula",                             |
# |        "mayBeStoriesCoOwner"                       |
# |      ],                                            |
# |      "id": "eagg-6py7",                            |
# |      "profileImageUrlLarge": "/api/users/eagg-...  |
# |      "profileImageUrlMedium": "/api/users/eagg...  |
# |      "profileImageUrlSmall": "/api/users/eagg-...  |
# |      "screenName": "Department of Licensing",      |
# |      "type": "interactive"                         |
# |    },                                              |
# |    "provenance": "official",                       |
# |    "publicationAppendEnabled": false,              |
# |    "publicationDate": 1655411270,                  |
# |    "publicationGroup": 16109923,                   |
# |    "publicationStage": "published",                |
# |    "query": {},                                    |
# |    "rights": [                                     |
# |      "read"                                        |
# |    ],                                              |
# |    "rowsUpdatedAt": 1676414279,                    |
# |    "rowsUpdatedBy": "nzip-b272",                   |
# |    "tableAuthor": {                                |
# |      "displayName": "Department of Licensing",     |
# |      "flags": [                                    |
# |        "acceptedEula",                             |
# |        "mayBeStoriesCoOwner"                       |
# |      ],                                            |
# |      "id": "eagg-6py7",                            |
# |      "profileImageUrlLarge": "/api/users/eagg-...  |
# |      "profileImageUrlMedium": "/api/users/eagg...  |
# |      "profileImageUrlSmall": "/api/users/eagg-...  |
# |      "screenName": "Department of Licensing",      |
# |      "type": "interactive"                         |
# |    },                                              |
# |    "tableId": 18748445,                            |
# |    "tags": [                                       |
# |      "tesla",                                      |
# |      "leaf",                                       |
# |      "nissan",                                     |
# |      "model 3",                                    |
# |      "dol",                                        |
# |      "department of licensing",                    |
# |      "green report",                               |
# |      "ev",                                         |
# |      "evs",                                        |
# |      "phev",                                       |
# |      "phevs",                                      |
# |      "bev",                                        |
# |      "bevs",                                       |
# |      "electric",                                   |
# |      "hybrid",                                     |
# |      "vehicle",                                    |
# |      "plug-in",                                    |
# |      "volt",                                       |
# |      "bolt",                                       |
# |      "chevy",                                      |
# |      "chevrolet",                                  |
# |      "car",                                        |
# |      "environment",                                |
# |      "clean energy",                               |
# |      "population",                                 |
# |      "hybrids",                                    |
# |      "plug-ins",                                   |
# |      "vehicles",                                   |
# |      "cars",                                       |
# |      "energy",                                     |
# |      "nhtsa",                                      |
# |      "rao_open_data",                              |
# |      "dol_open_data",                              |
# |      "rao_ev",                                     |
# |      "rao_veh"                                     |
# |    ],                                              |
# |    "totalTimesRated": 0,                           |
# |    "viewCount": 23105,                             |
# |    "viewLastModified": 1676414230,                 |
# |    "viewType": "tabular"                           |
# |  }                                                 |
# |}                                                   |
# ------------------------------------------------------

# %%
dfViewRaw = snow_df.select(snow_df.meta.getItem("view").alias("view"))
dfViewRaw.show()

#dfApprovals = dfViewRaw.select(F.col("view").getItem("approvals").alias("approvals"))
dfApprovals = dfViewRaw.selectExpr("view:approvals as approvals")
dfApprovals.show()
# Out:
# ------------------------------------------------------
# |"VIEW"                                              |
# ------------------------------------------------------
# |{                                                   |
# |  "approvals": [                                    |
# |    {                                               |
# |      "reviewedAt": 1559931329,                     |
# |      "reviewedAutomatically": true,                |
# |      "state": "approved",                          |
# |      "submissionDetails": {                        |
# |        "permissionType": "READ"                    |
# |      },                                            |
# |      "submissionId": 4774840,                      |
# |      "submissionObject": "public_audience_requ...  |
# |      "submissionOutcome": "change_audience",       |
# |      "submissionOutcomeApplication": {             |
# |        "failureCount": 0,                          |
# |        "status": "success"                         |
# |      },                                            |
# |      "submittedAt": 1559931329,                    |
# |      "submitter": {                                |
# |        "displayName": "Department of Licensing",   |
# |        "id": "eagg-6py7"                           |
# |      },                                            |
# |      "workflowId": 2106                            |
# |    }                                               |
# |  ],                                                |
# |  "assetType": "dataset",                           |
# |  "attribution": "Washington State Department o...  |
# |  "averageRating": 0,                               |
# |  "category": "Transportation",                     |
# |  "clientContext": {                                |
# |    "clientContextVariables": [],                   |
# |    "inheritedVariables": {}                        |
# |  },                                                |
# |  "columns": [                                      |
# |    {                                               |
# |      "dataTypeName": "meta_data",                  |
# |      "fieldName": ":sid",                          |
# |      "flags": [                                    |
# |        "hidden"                                    |
# |      ],                                            |
# |      "format": {},                                 |
# |      "id": -1,                                     |
# |      "name": "sid",                                |
# |      "position": 0,                                |
# |      "renderTypeName": "meta_data"                 |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "meta_data",                  |
# |      "fieldName": ":id",                           |
# |      "flags": [                                    |
# |        "hidden"                                    |
# |      ],                                            |
# |      "format": {},                                 |
# |      "id": -1,                                     |
# |      "name": "id",                                 |
# |      "position": 0,                                |
# |      "renderTypeName": "meta_data"                 |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "meta_data",                  |
# |      "fieldName": ":position",                     |
# |      "flags": [                                    |
# |        "hidden"                                    |
# |      ],                                            |
# |      "format": {},                                 |
# |      "id": -1,                                     |
# |      "name": "position",                           |
# |      "position": 0,                                |
# |      "renderTypeName": "meta_data"                 |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "meta_data",                  |
# |      "fieldName": ":created_at",                   |
# |      "flags": [                                    |
# |        "hidden"                                    |
# |      ],                                            |
# |      "format": {},                                 |
# |      "id": -1,                                     |
# |      "name": "created_at",                         |
# |      "position": 0,                                |
# |      "renderTypeName": "meta_data"                 |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "meta_data",                  |
# |      "fieldName": ":created_meta",                 |
# |      "flags": [                                    |
# |        "hidden"                                    |
# |      ],                                            |
# |      "format": {},                                 |
# |      "id": -1,                                     |
# |      "name": "created_meta",                       |
# |      "position": 0,                                |
# |      "renderTypeName": "meta_data"                 |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "meta_data",                  |
# |      "fieldName": ":updated_at",                   |
# |      "flags": [                                    |
# |        "hidden"                                    |
# |      ],                                            |
# |      "format": {},                                 |
# |      "id": -1,                                     |
# |      "name": "updated_at",                         |
# |      "position": 0,                                |
# |      "renderTypeName": "meta_data"                 |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "meta_data",                  |
# |      "fieldName": ":updated_meta",                 |
# |      "flags": [                                    |
# |        "hidden"                                    |
# |      ],                                            |
# |      "format": {},                                 |
# |      "id": -1,                                     |
# |      "name": "updated_meta",                       |
# |      "position": 0,                                |
# |      "renderTypeName": "meta_data"                 |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "meta_data",                  |
# |      "fieldName": ":meta",                         |
# |      "flags": [                                    |
# |        "hidden"                                    |
# |      ],                                            |
# |      "format": {},                                 |
# |      "id": -1,                                     |
# |      "name": "meta",                               |
# |      "position": 0,                                |
# |      "renderTypeName": "meta_data"                 |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "text",                       |
# |      "description": "The 1st 10 characters of ...  |
# |      "fieldName": "vin_1_10",                      |
# |      "format": {},                                 |
# |      "id": 561974342,                              |
# |      "name": "VIN (1-10)",                         |
# |      "position": 1,                                |
# |      "renderTypeName": "text",                     |
# |      "tableColumnId": 79309982                     |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "text",                       |
# |      "description": "The county in which the r...  |
# |      "fieldName": "county",                        |
# |      "format": {},                                 |
# |      "id": 561974343,                              |
# |      "name": "County",                             |
# |      "position": 2,                                |
# |      "renderTypeName": "text",                     |
# |      "tableColumnId": 79309981                     |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "text",                       |
# |      "description": "The city in which the reg...  |
# |      "fieldName": "city",                          |
# |      "format": {},                                 |
# |      "id": 561974344,                              |
# |      "name": "City",                               |
# |      "position": 3,                                |
# |      "renderTypeName": "text",                     |
# |      "tableColumnId": 79309980                     |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "text",                       |
# |      "description": "The state in which the re...  |
# |      "fieldName": "state",                         |
# |      "format": {},                                 |
# |      "id": 561974345,                              |
# |      "name": "State",                              |
# |      "position": 4,                                |
# |      "renderTypeName": "text",                     |
# |      "tableColumnId": 80218820                     |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "text",                       |
# |      "description": "The 5 digit zip code in w...  |
# |      "fieldName": "zip_code",                      |
# |      "format": {},                                 |
# |      "id": 561974346,                              |
# |      "name": "Postal Code",                        |
# |      "position": 5,                                |
# |      "renderTypeName": "text",                     |
# |      "tableColumnId": 79309971                     |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "text",                       |
# |      "description": "The model year of the veh...  |
# |      "fieldName": "model_year",                    |
# |      "format": {},                                 |
# |      "id": 561974347,                              |
# |      "name": "Model Year",                         |
# |      "position": 6,                                |
# |      "renderTypeName": "text",                     |
# |      "tableColumnId": 79309970                     |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "text",                       |
# |      "description": "The manufacturer of the v...  |
# |      "fieldName": "make",                          |
# |      "format": {},                                 |
# |      "id": 561974348,                              |
# |      "name": "Make",                               |
# |      "position": 7,                                |
# |      "renderTypeName": "text",                     |
# |      "tableColumnId": 79309979                     |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "text",                       |
# |      "description": "The model of the vehicle,...  |
# |      "fieldName": "model",                         |
# |      "format": {},                                 |
# |      "id": 561974349,                              |
# |      "name": "Model",                              |
# |      "position": 8,                                |
# |      "renderTypeName": "text",                     |
# |      "tableColumnId": 79309978                     |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "text",                       |
# |      "description": "This distinguishes the ve...  |
# |      "fieldName": "ev_type",                       |
# |      "format": {                                   |
# |        "align": "right"                            |
# |      },                                            |
# |      "id": 561974350,                              |
# |      "name": "Electric Vehicle Type",              |
# |      "position": 9,                                |
# |      "renderTypeName": "text",                     |
# |      "tableColumnId": 79309976                     |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "text",                       |
# |      "description": "This categorizes vehicle ...  |
# |      "fieldName": "cafv_type",                     |
# |      "format": {                                   |
# |        "align": "right"                            |
# |      },                                            |
# |      "id": 561974351,                              |
# |      "name": "Clean Alternative Fuel Vehicle (...  |
# |      "position": 10,                               |
# |      "renderTypeName": "text",                     |
# |      "tableColumnId": 79309975                     |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "number",                     |
# |      "description": "Describes how far a vehic...  |
# |      "fieldName": "electric_range",                |
# |      "format": {                                   |
# |        "align": "right"                            |
# |      },                                            |
# |      "id": 561974352,                              |
# |      "name": "Electric Range",                     |
# |      "position": 11,                               |
# |      "renderTypeName": "number",                   |
# |      "tableColumnId": 79309974                     |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "number",                     |
# |      "description": "This is the lowest Manufa...  |
# |      "fieldName": "base_msrp",                     |
# |      "format": {                                   |
# |        "align": "right"                            |
# |      },                                            |
# |      "id": 561974353,                              |
# |      "name": "Base MSRP",                          |
# |      "position": 12,                               |
# |      "renderTypeName": "number",                   |
# |      "tableColumnId": 79310342                     |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "number",                     |
# |      "description": "The specific section of W...  |
# |      "fieldName": "legislative_district",          |
# |      "format": {                                   |
# |        "align": "center"                           |
# |      },                                            |
# |      "id": 561974354,                              |
# |      "name": "Legislative District",               |
# |      "position": 13,                               |
# |      "renderTypeName": "number",                   |
# |      "tableColumnId": 140620854                    |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "text",                       |
# |      "description": "Unique number assigned to...  |
# |      "fieldName": "dol_vehicle_id",                |
# |      "format": {},                                 |
# |      "id": 561974355,                              |
# |      "name": "DOL Vehicle ID",                     |
# |      "position": 14,                               |
# |      "renderTypeName": "text",                     |
# |      "tableColumnId": 82051518                     |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "point",                      |
# |      "description": "The center of the ZIP Cod...  |
# |      "fieldName": "geocoded_column",               |
# |      "format": {},                                 |
# |      "id": 561974356,                              |
# |      "name": "Vehicle Location",                   |
# |      "position": 15,                               |
# |      "renderTypeName": "point",                    |
# |      "tableColumnId": 87270515                     |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "text",                       |
# |      "description": "This is the electric powe...  |
# |      "fieldName": "electric_utility",              |
# |      "format": {},                                 |
# |      "id": 561974358,                              |
# |      "name": "Electric Utility",                   |
# |      "position": 17,                               |
# |      "renderTypeName": "text",                     |
# |      "tableColumnId": 141400529                    |
# |    },                                              |
# |    {                                               |
# |      "dataTypeName": "text",                       |
# |      "description": "The census tract identifi...  |
# |      "fieldName": "_2020_census_tract",            |
# |      "format": {},                                 |
# |      "id": 561974362,                              |
# |      "name": "2020 Census Tract",                  |
# |      "position": 18,                               |
# |      "renderTypeName": "text",                     |
# |      "tableColumnId": 142655072                    |
# |    },                                              |
# |    {                                               |
# |      "computationStrategy": {                      |
# |        "parameters": {                             |
# |          "primary_key": "_feature_id",             |
# |          "region": "_x4ys-rtnd"                    |
# |        },                                          |
# |        "source_columns": [                         |
# |          "geocoded_column"                         |
# |        ],                                          |
# |        "type": "georegion_match_on_point"          |
# |      },                                            |
# |      "dataTypeName": "number",                     |
# |      "description": "",                            |
# |      "fieldName": ":@computed_region_x4ys_rtnd",   |
# |      "format": {},                                 |
# |      "id": 561974360,                              |
# |      "name": "Counties",                           |
# |      "position": 19,                               |
# |      "renderTypeName": "number",                   |
# |      "tableColumnId": 87270516                     |
# |    },                                              |
# |    {                                               |
# |      "computationStrategy": {                      |
# |        "parameters": {                             |
# |          "primary_key": "_feature_id",             |
# |          "region": "_fny7-vc3j"                    |
# |        },                                          |
# |        "source_columns": [                         |
# |          "geocoded_column"                         |
# |        ],                                          |
# |        "type": "georegion_match_on_point"          |
# |      },                                            |
# |      "dataTypeName": "number",                     |
# |      "description": "",                            |
# |      "fieldName": ":@computed_region_fny7_vc3j",   |
# |      "format": {},                                 |
# |      "id": 561974361,                              |
# |      "name": "Congressional Districts",            |
# |      "position": 20,                               |
# |      "renderTypeName": "number",                   |
# |      "tableColumnId": 87270517                     |
# |    },                                              |
# |    {                                               |
# |      "computationStrategy": {                      |
# |        "parameters": {                             |
# |          "primary_key": "_feature_id",             |
# |          "region": "_8ddd-yn5v"                    |
# |        },                                          |
# |        "source_columns": [                         |
# |          "geocoded_column"                         |
# |        ],                                          |
# |        "type": "georegion_match_on_point"          |
# |      },                                            |
# |      "dataTypeName": "number",                     |
# |      "description": "",                            |
# |      "fieldName": ":@computed_region_8ddd_yn5v",   |
# |      "format": {},                                 |
# |      "id": 561974359,                              |
# |      "name": "WAOFM - GIS - Legislative Distri...  |
# |      "position": 21,                               |
# |      "renderTypeName": "number",                   |
# |      "tableColumnId": 87270518                     |
# |    }                                               |
# |  ],                                                |
# |  "createdAt": 1555435581,                          |
# |  "description": "This dataset shows the Batter...  |
# |  "displayType": "table",                           |
# |  "downloadCount": 52628,                           |
# |  "flags": [                                        |
# |    "default",                                      |
# |    "ownerMayBeContacted",                          |
# |    "restorable",                                   |
# |    "restorePossibleForType"                        |
# |  ],                                                |
# |  "grants": [                                       |
# |    {                                               |
# |      "flags": [                                    |
# |        "public"                                    |
# |      ],                                            |
# |      "inherited": false,                           |
# |      "type": "viewer"                              |
# |    }                                               |
# |  ],                                                |
# |  "hideFromCatalog": false,                         |
# |  "hideFromDataJson": false,                        |
# |  "id": "f6w7-q2d2",                                |
# |  "metadata": {                                     |
# |    "availableDisplayTypes": [                      |
# |      "table",                                      |
# |      "fatrow",                                     |
# |      "page"                                        |
# |    ],                                              |
# |    "custom_fields": {                              |
# |      "Identification": {                           |
# |        "Metadata Language": "English",             |
# |        "Originator": "Research and Analysis Of...  |
# |      },                                            |
# |      "Notes": {                                    |
# |        "1. ": "A Battery Electric Vehicle (BEV...  |
# |        "2. ": "Clean Alternative Fuel Vehicle ...  |
# |        "3. ": "Monthly count of vehicles for a...  |
# |        "4. ": "Electric Range is no longer mai...  |
# |        "5. ": "Field 'Electric Utility' was ad...  |
# |        "6. ": "Field '2020 Census Tract' was a...  |
# |      },                                            |
# |      "Temporal": {                                 |
# |        "Period of Time": "Data includes Batter...  |
# |        "Posting Frequency": "Monthly"              |
# |      }                                             |
# |    },                                              |
# |    "rowLabel": "Vehicle"                           |
# |  },                                                |
# |  "name": "Electric Vehicle Population Data",       |
# |  "newBackend": true,                               |
# |  "numberOfComments": 0,                            |
# |  "oid": 38591322,                                  |
# |  "owner": {                                        |
# |    "displayName": "Department of Licensing",       |
# |    "flags": [                                      |
# |      "acceptedEula",                               |
# |      "mayBeStoriesCoOwner"                         |
# |    ],                                              |
# |    "id": "eagg-6py7",                              |
# |    "profileImageUrlLarge": "/api/users/eagg-6p...  |
# |    "profileImageUrlMedium": "/api/users/eagg-6...  |
# |    "profileImageUrlSmall": "/api/users/eagg-6p...  |
# |    "screenName": "Department of Licensing",        |
# |    "type": "interactive"                           |
# |  },                                                |
# |  "provenance": "official",                         |
# |  "publicationAppendEnabled": false,                |
# |  "publicationDate": 1655411270,                    |
# |  "publicationGroup": 16109923,                     |
# |  "publicationStage": "published",                  |
# |  "query": {},                                      |
# |  "rights": [                                       |
# |    "read"                                          |
# |  ],                                                |
# |  "rowsUpdatedAt": 1676414279,                      |
# |  "rowsUpdatedBy": "nzip-b272",                     |
# |  "tableAuthor": {                                  |
# |    "displayName": "Department of Licensing",       |
# |    "flags": [                                      |
# |      "acceptedEula",                               |
# |      "mayBeStoriesCoOwner"                         |
# |    ],                                              |
# |    "id": "eagg-6py7",                              |
# |    "profileImageUrlLarge": "/api/users/eagg-6p...  |
# |    "profileImageUrlMedium": "/api/users/eagg-6...  |
# |    "profileImageUrlSmall": "/api/users/eagg-6p...  |
# |    "screenName": "Department of Licensing",        |
# |    "type": "interactive"                           |
# |  },                                                |
# |  "tableId": 18748445,                              |
# |  "tags": [                                         |
# |    "tesla",                                        |
# |    "leaf",                                         |
# |    "nissan",                                       |
# |    "model 3",                                      |
# |    "dol",                                          |
# |    "department of licensing",                      |
# |    "green report",                                 |
# |    "ev",                                           |
# |    "evs",                                          |
# |    "phev",                                         |
# |    "phevs",                                        |
# |    "bev",                                          |
# |    "bevs",                                         |
# |    "electric",                                     |
# |    "hybrid",                                       |
# |    "vehicle",                                      |
# |    "plug-in",                                      |
# |    "volt",                                         |
# |    "bolt",                                         |
# |    "chevy",                                        |
# |    "chevrolet",                                    |
# |    "car",                                          |
# |    "environment",                                  |
# |    "clean energy",                                 |
# |    "population",                                   |
# |    "hybrids",                                      |
# |    "plug-ins",                                     |
# |    "vehicles",                                     |
# |    "cars",                                         |
# |    "energy",                                       |
# |    "nhtsa",                                        |
# |    "rao_open_data",                                |
# |    "dol_open_data",                                |
# |    "rao_ev",                                       |
# |    "rao_veh"                                       |
# |  ],                                                |
# |  "totalTimesRated": 0,                             |
# |  "viewCount": 23105,                               |
# |  "viewLastModified": 1676414230,                   |
# |  "viewType": "tabular"                             |
# |}                                                   |
# ------------------------------------------------------
#
# ------------------------------------------------------
# |"APPROVALS"                                         |
# ------------------------------------------------------
# |[                                                   |
# |  {                                                 |
# |    "reviewedAt": 1559931329,                       |
# |    "reviewedAutomatically": true,                  |
# |    "state": "approved",                            |
# |    "submissionDetails": {                          |
# |      "permissionType": "READ"                      |
# |    },                                              |
# |    "submissionId": 4774840,                        |
# |    "submissionObject": "public_audience_request",  |
# |    "submissionOutcome": "change_audience",         |
# |    "submissionOutcomeApplication": {               |
# |      "failureCount": 0,                            |
# |      "status": "success"                           |
# |    },                                              |
# |    "submittedAt": 1559931329,                      |
# |    "submitter": {                                  |
# |      "displayName": "Department of Licensing",     |
# |      "id": "eagg-6py7"                             |
# |    },                                              |
# |    "workflowId": 2106                              |
# |  }                                                 |
# |]                                                   |
# ------------------------------------------------------
